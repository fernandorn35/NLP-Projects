# %% [markdown]
# To Anonymize Your Python Requests With Tor, checked this: https://www.youtube.com/watch?v=wJfa0qEzpJc&t=59s

# %% [markdown]
# To get a basic understanding on how to scrape Twitter data with snscrape, this resource was very helpful: https://www.youtube.com/watch?v=QLIYJoRvd-M

# %% [markdown]
# On how to save scraped Data to a Database with Python: https://www.youtube.com/watch?v=xBbK2kvHXwE

# %% [markdown]
# On python open():
#
# *https://www.programiz.com/python-programming/methods/built-in/open
#
# *https://stackoverflow.com/questions/19774357/how-to-open-read-write-file-and-recreate-the-file

# %% [markdown]
# On saving scraped data to Database: https://www.youtube.com/watch?v=xBbK2kvHXwE&t=151s

# %%
import json, os, sys
import snscrape.modules.twitter as sntwitter
import datetime, time, requests
from datetime import datetime 
from datetime import date
from datetime import timedelta
import sqlite3

# %%
import requests
import time, random
from stem import Signal
from stem.control import Controller
from fake_useragent import UserAgent
import random, time

# %%
conn = sqlite3.connect('test_database2.db')
c = conn.cursor()

# %%
c.execute('CREATE TABLE IF NOT EXISTS tweets_china_2 (Datetime DATE, Tweet_Id TEXT, Text TEXT, Username TEXT)')
conn.commit()

# %%
language = 'lang:zh'  #set language to Chinese
location = '36.186107, 105.163097, 2010km'

# %%
proxies = {
    'http': 'socks5://127.0.0.1:9050',
    'https': 'socks5://127.0.0.1:9050'
}

url = 'https://ident.me'

# %%
headers = { 'User-Agent': UserAgent().random }
requests.get(url, proxies=proxies, headers=headers).text
# Out:
# '185.220.101.58'

# %%
def renew_ip():
    with Controller.from_port(port=9051) as c:
        c.authenticate(password='kalilinux')
        c.signal(Signal.NEWNYM)

# %%
current_datetime = datetime.now()
print(current_datetime)
# Out:
# 2022-08-02 01:00:56.164385

# %%
date = date.today()
print(date)
# Out:
# 2022-08-02

# %%
previous_hour = current_datetime - timedelta(hours=1)
print(previous_hour)
# Out:
# 2022-08-02 00:00:56.164385

# %%
tweet_list1 = []

# %%
Tweets = "/mnt/pub/scrape/Twitter/Chinese/'ChineseTweets' + str(date) + '.json'"

# %%
 for r in range (10):
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(language, 'since:current_datetime until:previous_hour').get_items()):
        if i>=500:
            break
        c.execute('''INSERT INTO tweets_china_2 VALUES(?,?,?,?)''', (tweet.date, tweet.id, tweet.content, tweet.user.username))
        #tweet_list1.append([tweet, tweet.date, tweet.id, tweet.content, tweet.user.username])
renew_ip()#
time.sleep(10)

# %%
conn.commit()

# %%
print('complete')
# Out:
# complete

# %%
c.execute('''SELECT * FROM tweets_china_2''')

# %%
results = c.fetchall()

# %%
print(results)
# Out:
�啥的都要少吃了，小日子回头又放污水😂', 'JingWong77'), ('2022-08-02 04:52:04+00:00', '1554329162001031169', '@SpokespersonCHN 唉。。。只會耍嘴砲嗎？🤣', '_iamblackjack_'), ('2022-08-02 04:52:04+00:00', '1554329160742469633', '@chilionyang @Captain_Kamui_ @muzi69936875 @wangjin06240224 @only1youPerfect @reborn_captain @ggbeer2 @sweetsugar66666 @syzfljm @jujinidexin1 @bluemic986 @aeer000 @hao422237244 @windz8964 @yutang9527 @TGTM_Official 台湾这种智障很多。为了博眼球，胡说八道。关键是有些人就喜欢看这些。', 'aerfa52284840'), ('2022-08-02 04:52:04+00:00', '1554329160587157506', '@psmj01 情場面粉金不換！？\n面具子你不要中他的美男計啊！', 'automatic554288'), ('2022-08-02 04:52:04+00:00', '1554329159677407232', '起风了，朋友们', 'DYLANYU23333734'), ('2022-08-02 04:52:04+00:00', '1554329159656435712', '沃我好久沒去西門了…', 'RikaAa__020804'), ('2022-08-02 04:52:04+00:00', '1554329159576342530', '「真正的困難在於，對人性抱持足夠的信念，去相信有人會在意這些事。」她說。 —《深入絕境：戰地記者瑪麗·柯爾文的生與死》第293頁。', 'purplemap'), ('2022-08-02 04:52:04+00:00', '1554329158855032832', '@mysun_001 建议脱支大佐先带头把自己亲妈杀掉，这样的大佐我敬你是一条汉子。既然要脱支先从自己做榜样，切断支那血缘，把中国人统统关进集中营（什么新纳粹😅😅）', 'venicemala_'), ('2022-08-02 04:52:03+00:00', '1554329158137679872', '@VOAChinese 我僅代表九千萬共產黨員之外的12.1億中國民眾支持美國軍方對中南海采取必要軍事措施！', 'ckho93393893'), ('2022-08-02 04:52:03+00:00', '1554329157999374336', '@cumingpower @big_ear_cat 是酒店故意放的风吧，这营销手段真是高啊 👍🤣', 'enjoygracelife'), ('2022-08-02 04:52:03+00:00', '1554329157747630080', '@yuxiangqingjie 大概率不会打', 'George50541315'), ('2022-08-02 04:52:03+00:00', '1554329157533925377', '@RFA_Chinese 发射导弹是飞行员自己的决定，于中国无关', 'Rrrrrrr02090717'), ('2022-08-02 04:52:03+00:00', '1554329157383106561', '為什麼我做什麼都不對', 'mapodofuuu'), ('2022-08-02 04:52:03+00:00', '1554329157110157312', '@PollyMigo @zhang_heqing 使命必达，东风催美不在话下。', '5VugZtl6X3d1cgB'), ('2022-08-02 04:52:03+ ...

# %%
print(len(results))
# Out:
# 10000

# %%
c.execute('''SELECT Tweet_Id FROM tweets_china_2''')

# %%
results1 = c.fetchall()

# %%
print(results1)
# Out:
# []

# %%
conn.close()

# %% [markdown]
# On python open():
#
# *https://www.programiz.com/python-programming/methods/built-in/open
#
# *https://stackoverflow.com/questions/19774357/how-to-open-read-write-file-and-recreate-the-file

# %% [markdown]
# For 'UnicodeEncodeError: 'charmap' codec can't encode characters' problem, checked this resource: https://stackoverflow.com/questions/27092833/unicodeencodeerror-charmap-codec-cant-encode-characters
